# %%
from langchain_community.chat_models.tongyi import ChatTongyi
from dotenv import load_dotenv

# 加载环境变量 .env 文件
load_dotenv()

chatLLM = ChatTongyi(
    model="qwen-plus",
)

# %%
from deepagents import create_deep_agent

def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"

agent = create_deep_agent(
    model=chatLLM,
    tools=[get_weather],
    system_prompt="You are a helpful assistant",
)

# Run the agent
agent.invoke(
    {"messages": [{"role": "user", "content": "what is the weather in sf"}]}
)
# Out:
# {'messages': [HumanMessage(content='what is the weather in sf', additional_kwargs={}, response_metadata={}, id='649430ca-a58d-4c3e-a108-a2f3a5ab084b'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_f06651ae0ce740389b9a59', 'type': 'function', 'function': {'name': 'get_weather', 'arguments': '{"city": "sf"}'}}]}, response_metadata={'model_name': 'qwen-plus', 'finish_reason': 'tool_calls', 'request_id': 'c63f3126-41ce-992c-b4c1-4aade6b1f9e7', 'token_usage': {'input_tokens': 5804, 'output_tokens': 19, 'total_tokens': 5823, 'prompt_tokens_details': {'cached_tokens': 0}}}, id='lc_run--019d4705-9852-78a1-bf3a-eb747d0e241c-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'sf'}, 'id': 'call_f06651ae0ce740389b9a59', 'type': 'tool_call'}], invalid_tool_calls=[]),
#   ToolMessage(content="It's always sunny in sf!", name='get_weather', id='a0449c74-aca3-4d20-b839-fd23418db43d', tool_call_id='call_f06651ae0ce740389b9a59'),
#   AIMessage(content="It's always sunny in SF! 🌞", additional_kwargs={}, response_metadata={'model_name': 'qwen-plus', 'finish_reason': 'stop', 'request_id': '3c52891b-8b84-9116-8b97-50700e42a601', 'token_usage': {'input_tokens': 5843, 'output_tokens': 10, 'total_tokens': 5853, 'prompt_tokens_details': {'cached_tokens': 0}}}, id='lc_run--019d4705-a164-7793-a749-c6770c3ee9c5-0', tool_calls=[], invalid_tool_calls=[])]}
