# %%
from langchain_community.chat_models.tongyi import ChatTongyi
from dotenv import load_dotenv

# 加载环境变量 .env 文件
load_dotenv()

chatLLM = ChatTongyi(
    model="qwen-plus",
)

# %% [markdown]
# ## 流式输出
# 流式输出主要是因为大模型的内容推理机制和模型推理速度太慢，为了更好的交互才采用的流式输出，如果不想使用流式输出，前提是推理内容小，推理速度足够快。

# %%
from langchain_core.messages import HumanMessage, SystemMessage

res = chatLLM.stream([
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="你是谁？")
], streaming=True)
for r in res:
    print("chat resp:", r.content)
# Out:
# chat resp: 你好
# chat resp: ！我是通
# chat resp: 义千问
# chat resp: （Qwen
# chat resp: ），阿里巴巴集团旗下的超
# chat resp: 大规模语言模型。
# chat resp: 我能够回答问题、创作
# chat resp: 文字，比如写故事、
# chat resp: 写公文、写邮件
# chat resp: 、写剧本、逻辑推理
# chat resp: 、编程等等，还能表达
# chat resp: 观点，玩游戏等。如果你
# chat resp: 有任何问题或需要帮助，
# chat resp: 欢迎随时告诉我！😊
# chat resp:
# chat resp:

# %% [markdown]
# ## 阻塞输出

# %%
from langchain_core.messages import HumanMessage, SystemMessage

res = chatLLM.invoke([
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="你是谁？")
])
print(res.content)
# Out:
# 你好！我是通义千问（Qwen），阿里巴巴集团旗下的超大规模语言模型。我能够回答问题、创作文字，比如写故事、写公文、写邮件、写剧本、逻辑推理、编程等等，还能表达观点，玩游戏等。如果你有任何问题或需要帮助，欢迎随时告诉我！😊

# %% [markdown]
# ## chatbot 示例
# 大模型相当于一个函数，它只会根据文本内容推理出内容，无状态数据。当做大模型应用时，为了稳定回答效果，都是尽量提供上下文，让问答效果更佳稳定。

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

res = chatLLM.invoke(
    [
        HumanMessage(content="Hi! I'm Bob"),
        AIMessage(content="Hello Bob! How can I assist you today?"),
        HumanMessage(content="What's my name?"),
    ]
)
print(res)
# Out:
# content='Your name is Bob! 😊' additional_kwargs={} response_metadata={'model_name': 'qwen-plus', 'finish_reason': 'stop', 'request_id': '705b55d4-67f0-985a-b9a6-bc5e7bf317f9', 'token_usage': {'input_tokens': 38, 'output_tokens': 7, 'total_tokens': 45, 'prompt_tokens_details': {'cached_tokens': 0}}} id='lc_run--019d46e3-8cf4-77f1-9de6-9c50eba4381c-0' tool_calls=[] invalid_tool_calls=[]
