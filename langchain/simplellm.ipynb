# %%
import os
from langchain_community.chat_models.tongyi import ChatTongyi
from dotenv import load_dotenv

# 加载环境变量 .env 文件
load_dotenv()

chatLLM = ChatTongyi(
    model=os.getenv("ALIYUN_TEXT_MODEL"),
)

# %% [markdown]
# ## 流式输出
# 流式输出主要是因为大模型的内容推理机制和模型推理速度太慢，为了更好的交互才采用的流式输出，如果不想使用流式输出，前提是推理内容小，推理速度足够快。

# %%
from langchain_core.messages import HumanMessage, SystemMessage

res = chatLLM.stream([
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="你是谁？")
])
for r in res:
    print("chat resp:", r.content)
# Out:
# chat resp: 你好
# chat resp: ！我是通
# chat resp: 义千问（Qwen
# chat resp: ），由阿里巴巴集团旗下的
# chat resp: 通义实验室自主研发的超
# chat resp: 大规模语言模型。我可以
# chat resp: 回答问题、创作文字，
# chat resp: 比如写故事、写公
# chat resp: 文、写邮件、写剧本
# chat resp: 、逻辑推理、编程等等
# chat resp: ，还能表达观点，玩游戏
# chat resp: 等。如果你有任何问题或
# chat resp: 需要帮助，随时告诉我！
# chat resp:
# chat resp:

# %% [markdown]
# ## 阻塞输出

# %%
from langchain_core.messages import HumanMessage, SystemMessage

res = chatLLM.invoke([
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="你是谁？")
])
print(res.content)
# Out:
# 你好！我是通义千问（Qwen），由通义实验室研发的超大规模语言模型。我可以回答问题、创作文字，比如写故事、写公文、写邮件、写剧本、逻辑推理、编程等等，还能表达观点，玩游戏等。如果你有任何问题或需要帮助，欢迎随时告诉我！

# %% [markdown]
# ## chatbot 示例
# 大模型相当于一个函数，它只会根据文本内容推理出内容，无状态数据。当做大模型应用时，为了稳定回答效果，都是尽量提供上下文，让问答效果更佳稳定。

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

res = chatLLM.invoke(
    [
        HumanMessage(content="Hi! I'm Bob"),
        AIMessage(content="Hello Bob! How can I assist you today?"),
        HumanMessage(content="What's my name?"),
    ]
)
print(res)
# Out:
# content='Your name is Bob! 😊' additional_kwargs={} response_metadata={'model_name': 'qwen3-max-2026-01-23', 'finish_reason': 'stop', 'request_id': '454bfe1f-372d-9b32-90fc-333d62081b36', 'token_usage': {'input_tokens': 38, 'output_tokens': 7, 'total_tokens': 45}} id='lc_run--019d6695-5583-74e0-83ef-c14129d7334d-0' tool_calls=[] invalid_tool_calls=[]
